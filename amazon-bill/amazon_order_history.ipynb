# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_order_history.csv")

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
# df.shape

# %%
# data cleaning
df.fillna(0)
df.head()
# Out:
#               order id                                              items  \
# 0  402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1  402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2  402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3  402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4  402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
#
#              to        date      total  shipping shipping_refund gift VAT  \
# 0  Adithya Ravi  2021-11-13  Rs.999.00  Rs. 0.00               0    0   0
# 1  Adithya Ravi  2021-11-07  Rs.449.00  Rs. 0.00               0    0   0
# 2  Adithya Ravi  2021-10-20  Rs.999.00  Rs. 0.00               0    0   0
# 3  Adithya Ravi  2021-09-06  Rs.749.00  Rs. 0.00               0    0   0
# 4  Adithya Ravi  2021-08-09  Rs.728.00  Rs. 0.00               0    0   0
#
#        refund   payments
# 0           0  UNKNOWN;
# 1           0  UNKNOWN;
# ...

# %%
df = df.iloc[:-1 , :]

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
df["total"] = df["total"].str.replace('Rs.','')
# Out:
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/4165432012.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["total"] = df["total"].str.replace('Rs.','')
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/4165432012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total"] = df["total"].str.replace('Rs.','')

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
df["shipping"] = df["shipping"].str.replace('Rs.','')
# Out:
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/3627800299.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["shipping"] = df["shipping"].str.replace('Rs.','')
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/3627800299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["shipping"] = df["shipping"].str.replace('Rs.','')

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
df["total"] = df["total"] = df["total"].str.replace(',','')
# Out:
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/398654358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total"] = df["total"] = df["total"].str.replace(',','')

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
df["total"] = df["total"].astype(float)
# Out:
# C:\Users\ravia\AppData\Local\Temp/ipykernel_13448/2161014376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total"] = df["total"].astype(float)

# %%
df
# Out:
#                order id                                              items  \
# 0   402-9860939-5364339  Noise Buds VS201 V2 Truly Wireless Earbuds wit...
# 1   402-6534609-3108364  DAHSHA Nylon Padded Cross Body Messenger Sling...
# 2   402-1859838-7006760  nakshathra Stainless Steel Oil Lantern with Gl...
# 3   402-2492846-2229160             Heelium Men Bamboo Formal Calf Socks;
# 4   402-4984339-4947563  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 5   402-7713831-8197147  SPHINX Artificial Marigold Door Toran (Yellow ...
# 6   402-8973429-5183557    GulshanCollection Women's Sling Bag (1_Beige);
# 7   402-0130957-4864308  Bildos Cotton & Khadi Cotton Reusable Super Br...
# 8   171-9911325-0890764  LEAWALL Bubble Shape Designer Water Bottles/Li...
# 9   171-9010401-5523558  TOYZTREND Ratna's Mikado Sticks Junior Game; M...
# 10  171-8068173-8621126  Sainik Jute Lunch Bag for Women and Men Multic...
# ...

# %%
df["total"].sum()
# Out:
# 23735.0

# %%
df.plot.bar(x='date', y='total', rot=90, figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='date'>
